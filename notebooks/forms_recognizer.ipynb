# %%
#  pip install azure-ai-formrecognizer

import os
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient
from dotenv import load_dotenv
load_dotenv()

endpoint = os.environ["AZURE_AI_SERVICES_URL"]
key = os.environ["AZURE_AI_SERVICES_KEY"]

credential = AzureKeyCredential(key)
client = DocumentAnalysisClient(endpoint, credential)

# %% [markdown]
# ## Layout Example

# %%
layout_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"

poller = client.begin_analyze_document_from_url("prebuilt-layout", layout_url)
result = poller.result()

for page in result.pages:
    print(f"Document Page {page.page_number} has {len(page.lines)} line(s), {len(page.words)} word(s),")
    print(f"and {len(page.selection_marks)} selection mark(s).")

    for i, line in enumerate(page.lines):
        print(f"  Line {i} has content: '{line.content}'.")
        print(f"    Its bounding box is:")
        print(f"      Upper left => X: {line.polygon[0].x}, Y= {line.polygon[0].y}")
        print(f"      Upper right => X: {line.polygon[1].x}, Y= {line.polygon[1].y}")
        print(f"      Lower right => X: {line.polygon[2].x}, Y= {line.polygon[2].y}")
        print(f"      Lower left => X: {line.polygon[3].x}, Y= {line.polygon[3].y}")

    for i, selection_mark in enumerate(page.selection_marks):
        print(f"  Selection Mark {i} is {selection_mark.state}.")
        print(f"    Its bounding box is:")
        print(f"      Upper left => X: {selection_mark.polygon[0].x}, Y= {selection_mark.polygon[0].y}")
        print(f"      Upper right => X: {selection_mark.polygon[1].x}, Y= {selection_mark.polygon[1].y}")
        print(f"      Lower right => X: {selection_mark.polygon[2].x}, Y= {selection_mark.polygon[2].y}")
        print(f"      Lower left => X: {selection_mark.polygon[3].x}, Y= {selection_mark.polygon[3].y}")

for style in result.styles:
    # Check the style and style confidence to see if text is handwritten.
    # Note that value '0.8' is used as an example.
    is_handwritten = style.is_handwritten and style.confidence > 0.8

    if is_handwritten:
        print("Handwritten content found:")
        for span in style.spans:
            print(f"  Content: {result.content[span.offset:span.offset+span.length]}")

print("The following tables were extracted:")

for i, table in enumerate(result.tables):
    print(f"  Table {i} has {table.row_count} rows and {table.column_count} columns.")
    for cell in table.cells:
        print(f"    Cell ({cell.row_index}, {cell.column_index}) has kind '{cell.kind}' and content: '{cell.content}'.")
# Out:
# Document Page 1 has 67 line(s), 413 word(s),
# and 14 selection mark(s).
#   Line 0 has content: 'UNITED STATES'.
#     Its bounding box is:
#       Upper left => X: 3.4669, Y= 0.6636
#       Upper right => X: 5.0236, Y= 0.6589
#       Lower right => X: 5.0236, Y= 0.8451
#       Lower left => X: 3.4669, Y= 0.8498
#   Line 1 has content: 'SECURITIES AND EXCHANGE COMMISSION'.
#     Its bounding box is:
#       Upper left => X: 2.168, Y= 0.8737
#       Upper right => X: 6.3129, Y= 0.8737
#       Lower right => X: 6.3129, Y= 1.0647
#       Lower left => X: 2.168, Y= 1.0647
#   Line 2 has content: 'Washington, D.C. 20549'.
#     Its bounding box is:
#       Upper left => X: 3.443, Y= 1.0885
#       Upper right => X: 5.057, Y= 1.0838
#       Lower right => X: 5.057, Y= 1.2509
#       Lower left => X: 3.443, Y= 1.2604
#   Line 3 has content: 'FORM 10-Q'.
#     Its bounding box is:
#       Upper left => X: 3.7104, Y= 1.3893
#       Upper right => X: 4.7944, Y= 1.3893
#       Lower right => X: 4.7944, Y= 1.5898
#       Lower left => X: 3.7104, Y= 1.5898
#   Line 4 has content: '☒'.
#     Its bounding box is:
#       Upper left => X: 0.6694, Y= 1.7746
#       Upper right => X: 0.7764, Y= 1.7746
#       Lower right => X: 0.7764, Y= 1.8833
#       Lower left => X: 0.6694, Y= 1.8833
#   Line 5 has content: 'QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF'.
#     Its bounding box is:
#       Upper left => X: 0.9694, Y= 1.7426
#       Upper right => X: 7.8601, Y= 1.7426
#       Lower right => X: 7.8601, Y= 1.9145
#       Lower left => X: 0.9694, Y= 1.9097
#   Line 6 has content: '1934'.
#     Its bounding box is:
#       Upper left => X: 0.9837, Y= 1.9336
#       Upper right => X: 1.2989, Y= 1.9336
#       Lower right => X: 1.2989, Y= 2.0625
#       Lower left => X: 0.9885, Y= 2.0577
#   Line 7 has content: 'For the Quarterly Period Ended March 31, 2020'.
#     Its bounding box is:
#       Upper left => X: 0.9789, Y= 2.1341
#       Upper right => X: 3.4621, Y= 2.1293
#       Lower right => X: 3.4621, Y= 2.2726
#       Lower left => X: 0.9789, Y= 2.2773
#   Line 8 has content: 'OR'.
#     Its bounding box is:
#       Upper left => X: 4.1306, Y= 2.2726
#       Upper right => X: 4.3598, Y= 2.2726
#       Lower right => X: 4.3646, Y= 2.4158
#       Lower left => X: 4.1306, Y= 2.411
#   Line 9 has content: '☐'.
#     Its bounding box is:
#       Upper left => X: 0.6694, Y= 2.6955
#       Upper right => X: 0.777, Y= 2.6955
#       Lower right => X: 0.777, Y= 2.8042
#       Lower left => X: 0.6694, Y= 2.8042
#   Line 10 has content: 'TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF'.
#     Its bounding box is:
#       Upper left => X: 0.9694, Y= 2.6641
#       Upper right => X: 7.8649, Y= 2.6641
#       Lower right => X: 7.8649, Y= 2.8312
#       Lower left => X: 0.9694, Y= 2.8312
#   Line 11 has content: '1934'.
#     Its bounding box is:
#       Upper left => X: 0.9837, Y= 2.8598
#       Upper right => X: 1.3084, Y= 2.855
#       Lower right => X: 1.3084, Y= 2.9935
#       Lower left => X: 0.9933, Y= 2.9887
#   Line 12 has content: 'For the Transition Period From'.
#     Its bounding box is:
#       Upper left => X: 0.9694, Y= 3.0556
#       Upper right => X: 2.6264, Y= 3.0556
#       Lower right => X: 2.6264, Y= 3.194
#       Lower left => X: 0.9694, Y= 3.1892
#   Line 13 has content: 'to'.
#     Its bounding box is:
#       Upper left => X: 3.1565, Y= 3.0794
#       Upper right => X: 3.2806, Y= 3.0747
#       Lower right => X: 3.2854, Y= 3.1654
#       Lower left => X: 3.1612, Y= 3.1654
#   Line 14 has content: 'Commission File Number 001-37845'.
#     Its bounding box is:
#       Upper left => X: 3.2185, Y= 3.2418
#       Upper right => X: 5.2671, Y= 3.237
#       Lower right => X: 5.2671, Y= 3.3802
#       Lower left => X: 3.2185, Y= 3.385
#   Line 15 has content: 'MICROSOFT CORPORATION'.
#     Its bounding box is:
#       Upper left => X: 2.5261, Y= 3.5378
#       Upper right => X: 5.9691, Y= 3.533
#       Lower right => X: 5.9691, Y= 3.7717
#       Lower left => X: 2.5261, Y= 3.7813
#   Line 16 has content: 'WASHINGTON'.
#     Its bounding box is:
#       Upper left => X: 1.9865, Y= 3.9293
#       Upper right => X: 2.8174, Y= 3.9293
#       Lower right => X: 2.8174, Y= 4.0677
#       Lower left => X: 1.9865, Y= 4.0677
#   Line 17 has content: '(STATE OF INCORPORATION)'.
#     Its bounding box is:
#       Upper left => X: 1.6857, Y= 4.0773
#       Upper right => X: 3.1135, Y= 4.0773
#       Lower right => X: 3.1135, Y= 4.2014
#       Lower left => X: 1.6857, Y= 4.2014
#   Line 18 has content: '91-1144442'.
#     Its bounding box is:
#       Upper left => X: 5.7542, Y= 3.934
#       Upper right => X: 6.418, Y= 3.9388
#       Lower right => X: 6.418, Y= 4.0677
#       Lower left => X: 5.7542, Y= 4.0629
#   Line 19 has content: '(I.R.S. ID)'.
#     Its bounding box is:
#       Upper left => X: 5.8593, Y= 4.082
#       Upper right => X: 6.3081, Y= 4.082
#       Lower right => X: 6.3081, Y= 4.2062
#       Lower left => X: 5.8593, Y= 4.2014
#   Line 20 has content: 'ONE MICROSOFT WAY, REDMOND, WASHINGTON 98052-6399'.
#     Its bounding box is:
#       Upper left => X: 2.5691, Y= 4.2491
#       Upper right => X: 5.9118, Y= 4.2491
#       Lower right => X: 5.9118, Y= 4.3828
#       Lower left => X: 2.5691, Y= 4.3876
#   Line 21 has content: '(425) 882-8080'.
#     Its bounding box is:
#       Upper left => X: 3.8346, Y= 4.3876
#       Upper right => X: 4.6272, Y= 4.3876
#       Lower right => X: 4.6272, Y= 4.5165
#       Lower left => X: 3.8393, Y= 4.5213
#   Line 22 has content: 'www.microsoft.com/investor'.
#     Its bounding box is:
#       Upper left => X: 3.4716, Y= 4.5165
#       Upper right => X: 5.0188, Y= 4.5165
#       Lower right => X: 5.0188, Y= 4.6454
#       Lower left => X: 3.4716, Y= 4.6454
#   Line 23 has content: 'Securities registered pursuant to Section 12(b) of the Act:'.
#     Its bounding box is:
#       Upper left => X: 0.616, Y= 4.717
#       Upper right => X: 3.634, Y= 4.7122
#       Lower right => X: 3.634, Y= 4.8555
#       Lower left => X: 0.616, Y= 4.8602
#   Line 24 has content: 'Title of each class'.
#     Its bounding box is:
#       Upper left => X: 0.616, Y= 4.9462
#       Upper right => X: 1.5711, Y= 4.951
#       Lower right => X: 1.5711, Y= 5.0799
#       Lower left => X: 0.616, Y= 5.0703
#   Line 25 has content: 'Trading Symbol'.
#     Its bounding box is:
#       Upper left => X: 4.3312, Y= 4.9462
#       Upper right => X: 5.1716, Y= 4.9462
#       Lower right => X: 5.1716, Y= 5.0846
#       Lower left => X: 4.3312, Y= 5.0846
#   Line 26 has content: 'Name of exchange on which registered'.
#     Its bounding box is:
#       Upper left => X: 5.5632, Y= 4.9462
#       Upper right => X: 7.6357, Y= 4.9462
#       Lower right => X: 7.6309, Y= 5.0894
#       Lower left => X: 5.5632, Y= 5.0846
#   Line 27 has content: 'Common stock, $0.00000625 par value per share'.
#     Its bounding box is:
#       Upper left => X: 0.616, Y= 5.1467
#       Upper right => X: 3.3522, Y= 5.1515
#       Lower right => X: 3.3522, Y= 5.2947
#       Lower left => X: 0.616, Y= 5.2852
#   Line 28 has content: 'MSFT'.
#     Its bounding box is:
#       Upper left => X: 4.5795, Y= 5.1563
#       Upper right => X: 4.9185, Y= 5.1515
#       Lower right => X: 4.9185, Y= 5.2708
#       Lower left => X: 4.5795, Y= 5.2756
#   Line 29 has content: 'NASDAQ'.
#     Its bounding box is:
#       Upper left => X: 6.3177, Y= 5.1372
#       Upper right => X: 6.8716, Y= 5.1372
#       Lower right => X: 6.8716, Y= 5.2947
#       Lower left => X: 6.3177, Y= 5.2947
#   Line 30 has content: '2.125% Notes due 2021'.
#     Its bounding box is:
#       Upper left => X: 0.6112, Y= 5.309
#       Upper right => X: 1.9292, Y= 5.3043
#       Lower right => X: 1.9292, Y= 5.4427
#       Lower left => X: 0.6112, Y= 5.4427
#   Line 31 has content: 'MSFT'.
#     Its bounding box is:
#       Upper left => X: 4.5747, Y= 5.3138
#       Upper right => X: 4.9185, Y= 5.309
#       Lower right => X: 4.9185, Y= 5.4332
#       Lower left => X: 4.5795, Y= 5.4284
#   Line 32 has content: 'NASDAQ'.
#     Its bounding box is:
#       Upper left => X: 6.3368, Y= 5.309
#       Upper right => X: 6.8716, Y= 5.309
#       Lower right => X: 6.8716, Y= 5.4379
#       Lower left => X: 6.3368, Y= 5.4332
#   Line 33 has content: '3.125% Notes due 2028'.
#     Its bounding box is:
#       Upper left => X: 0.616, Y= 5.4714
#       Upper right => X: 1.9388, Y= 5.4714
#       Lower right => X: 1.9388, Y= 5.6003
#       Lower left => X: 0.616, Y= 5.6003
#   Line 34 has content: 'MSFT'.
#     Its bounding box is:
#       Upper left => X: 4.5747, Y= 5.4761
#       Upper right => X: 4.9138, Y= 5.4714
#       Lower right => X: 4.9138, Y= 5.5907
#       Lower left => X: 4.5843, Y= 5.5907
#   Line 35 has content: 'NASDAQ'.
#     Its bounding box is:
#       Upper left => X: 6.3368, Y= 5.4761
#       Upper right => X: 6.8669, Y= 5.4761
#       Lower right => X: 6.8669, Y= 5.5955
#       Lower left => X: 6.3368, Y= 5.5955
#   Line 36 has content: '2.625% Notes due 2033'.
#     Its bounding box is:
#       Upper left => X: 0.6112, Y= 5.6289
#       Upper right => X: 1.9292, Y= 5.6289
#       Lower right => X: 1.9292, Y= 5.7578
#       Lower left => X: 0.6112, Y= 5.7578
#   Line 37 has content: 'MSFT'.
#     Its bounding box is:
#       Upper left => X: 4.5747, Y= 5.6146
#       Upper right => X: 4.9329, Y= 5.6146
#       Lower right => X: 4.9329, Y= 5.7674
#       Lower left => X: 4.5747, Y= 5.7674
#   Line 38 has content: 'NASDAQ'.
#     Its bounding box is:
#       Upper left => X: 6.332, Y= 5.6289
#       Upper right => X: 6.8764, Y= 5.6289
#       Lower right => X: 6.8764, Y= 5.753
#       Lower left => X: 6.332, Y= 5.753
#   Line 39 has content: 'Securities registered pursuant to Section 12(g) of the Act:'.
#     Its bounding box is:
#       Upper left => X: 0.6065, Y= 5.8247
#       Upper right => X: 3.6292, Y= 5.8199
#       Lower right => X: 3.6292, Y= 5.9631
#       Lower left => X: 0.6065, Y= 5.9631
#   Line 40 has content: 'NONE'.
#     Its bounding box is:
#       Upper left => X: 0.6112, Y= 6.0538
#       Upper right => X: 0.9789, Y= 6.0538
#       Lower right => X: 0.9742, Y= 6.178
#       Lower left => X: 0.6112, Y= 6.1732
#   Line 41 has content: 'Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange'.
#     Its bounding box is:
#       Upper left => X: 0.6303, Y= 6.2448
#       Upper right => X: 7.8553, Y= 6.24
#       Lower right => X: 7.8553, Y= 6.3832
#       Lower left => X: 0.6303, Y= 6.3832
#   Line 42 has content: 'Act of 1934 during the preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has'.
#     Its bounding box is:
#       Upper left => X: 0.6351, Y= 6.3832
#       Upper right => X: 7.8553, Y= 6.3832
#       Lower right => X: 7.8553, Y= 6.5265
#       Lower left => X: 0.6351, Y= 6.5217
#   Line 43 has content: 'been subject to such filing requirements for the past 90 days. Yes'.
#     Its bounding box is:
#       Upper left => X: 0.6351, Y= 6.5265
#       Upper right => X: 4.1831, Y= 6.5265
#       Lower right => X: 4.1831, Y= 6.6697
#       Lower left => X: 0.6351, Y= 6.6697
#   Line 44 has content: 'No'.
#     Its bounding box is:
#       Upper left => X: 4.4697, Y= 6.5408
#       Upper right => X: 4.6368, Y= 6.5456
#       Lower right => X: 4.6368, Y= 6.6411
#       Lower left => X: 4.4697, Y= 6.6411
#   Line 45 has content: 'Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule'.
#     Its bounding box is:
#       Upper left => X: 0.6399, Y= 6.727
#       Upper right => X: 7.8506, Y= 6.727
#       Lower right => X: 7.8506, Y= 6.8607
#       Lower left => X: 0.6399, Y= 6.8607
#   Line 46 has content: '405 of Regulation S-T (§232.405 of this chapter) during the preceding 12 months (or for such shorter period that the registrant was required to'.
#     Its bounding box is:
#       Upper left => X: 0.6399, Y= 6.8655
#       Upper right => X: 7.8601, Y= 6.8655
#       Lower right => X: 7.8601, Y= 6.9991
#       Lower left => X: 0.6399, Y= 6.9944
#   Line 47 has content: 'submit such files). Yes'.
#     Its bounding box is:
#       Upper left => X: 0.6351, Y= 7.0087
#       Upper right => X: 1.9149, Y= 7.0087
#       Lower right => X: 1.9149, Y= 7.1376
#       Lower left => X: 0.6351, Y= 7.1376
#   Line 48 has content: 'No'.
#     Its bounding box is:
#       Upper left => X: 2.1775, Y= 7.0278
#       Upper right => X: 2.3494, Y= 7.0278
#       Lower right => X: 2.3494, Y= 7.1185
#       Lower left => X: 2.1823, Y= 7.1185
#   Line 49 has content: 'Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting'.
#     Its bounding box is:
#       Upper left => X: 0.6303, Y= 7.2044
#       Upper right => X: 7.8506, Y= 7.2092
#       Lower right => X: 7.8506, Y= 7.3477
#       Lower left => X: 0.6303, Y= 7.3429
#   Line 50 has content: 'company, or an emerging growth company. See the definitions of "large accelerated filer," "accelerated filer," "smaller reporting company,"'.
#     Its bounding box is:
#       Upper left => X: 0.6303, Y= 7.3477
#       Upper right => X: 7.8506, Y= 7.3429
#       Lower right => X: 7.8506, Y= 7.4861
#       Lower left => X: 0.6303, Y= 7.4909
#   Line 51 has content: 'and "emerging growth company" in Rule 12b-2 of the Exchange Act.'.
#     Its bounding box is:
#       Upper left => X: 0.6351, Y= 7.4813
#       Upper right => X: 4.2022, Y= 7.4766
#       Lower right => X: 4.2022, Y= 7.615
#       Lower left => X: 0.6351, Y= 7.6198
#   Line 52 has content: 'Large accelerated filer'.
#     Its bounding box is:
#       Upper left => X: 0.6351, Y= 7.6866
#       Upper right => X: 1.8576, Y= 7.6866
#       Lower right => X: 1.8624, Y= 7.8203
#       Lower left => X: 0.6351, Y= 7.8299
#   Line 53 has content: 'Accelerated filer'.
#     Its bounding box is:
#       Upper left => X: 5.3149, Y= 7.6866
#       Upper right => X: 6.1935, Y= 7.6866
#       Lower right => X: 6.1935, Y= 7.8155
#       Lower left => X: 5.3149, Y= 7.8155
#   Line 54 has content: 'Non-accelerated filer'.
#     Its bounding box is:
#       Upper left => X: 0.6351, Y= 7.8681
#       Upper right => X: 1.7573, Y= 7.8681
#       Lower right => X: 1.7573, Y= 7.9922
#       Lower left => X: 0.6351, Y= 7.9922
#   Line 55 has content: 'Smaller reporting company'.
#     Its bounding box is:
#       Upper left => X: 5.3101, Y= 7.8633
#       Upper right => X: 6.7522, Y= 7.8728
#       Lower right => X: 6.7522, Y= 8.0065
#       Lower left => X: 5.3101, Y= 7.997
#   Line 56 has content: 'Emerging growth company'.
#     Its bounding box is:
#       Upper left => X: 5.3292, Y= 8.0399
#       Upper right => X: 6.7522, Y= 8.0399
#       Lower right => X: 6.7522, Y= 8.1784
#       Lower left => X: 5.3292, Y= 8.1784
#   Line 57 has content: 'If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying'.
#     Its bounding box is:
#       Upper left => X: 0.6399, Y= 8.2357
#       Upper right => X: 7.8506, Y= 8.2357
#       Lower right => X: 7.8506, Y= 8.3789
#       Lower left => X: 0.6399, Y= 8.3789
#   Line 58 has content: 'with any new or revised financial accounting standards provided pursuant to Section 13(a) of the Exchange Act.'.
#     Its bounding box is:
#       Upper left => X: 0.6351, Y= 8.3885
#       Upper right => X: 6.461, Y= 8.3885
#       Lower right => X: 6.461, Y= 8.5269
#       Lower left => X: 0.6351, Y= 8.5269
#   Line 59 has content: 'Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act).'.
#     Its bounding box is:
#       Upper left => X: 0.6399, Y= 8.5938
#       Upper right => X: 6.4323, Y= 8.5938
#       Lower right => X: 6.4371, Y= 8.7322
#       Lower left => X: 0.6399, Y= 8.7322
#   Line 60 has content: 'Yes'.
#     Its bounding box is:
#       Upper left => X: 6.4323, Y= 8.5603
#       Upper right => X: 6.7284, Y= 8.5603
#       Lower right => X: 6.7284, Y= 8.7513
#       Lower left => X: 6.4371, Y= 8.7513
#   Line 61 has content: 'No'.
#     Its bounding box is:
#       Upper left => X: 7.0101, Y= 8.6128
#       Upper right => X: 7.2011, Y= 8.6128
#       Lower right => X: 7.1963, Y= 8.7131
#       Lower left => X: 7.0101, Y= 8.7083
#   Line 62 has content: 'Indicate the number of shares outstanding of each of the issuer's classes of common stock, as of the latest practicable date.'.
#     Its bounding box is:
#       Upper left => X: 0.6303, Y= 8.7943
#       Upper right => X: 6.9385, Y= 8.7943
#       Lower right => X: 6.9385, Y= 8.928
#       Lower left => X: 0.6303, Y= 8.928
#   Line 63 has content: 'Class'.
#     Its bounding box is:
#       Upper left => X: 0.6447, Y= 9.0425
#       Upper right => X: 0.9169, Y= 9.0521
#       Lower right => X: 0.9169, Y= 9.224
#       Lower left => X: 0.6399, Y= 9.2144
#   Line 64 has content: 'Outstanding as of April 24, 2020'.
#     Its bounding box is:
#       Upper left => X: 6.1124, Y= 9.0855
#       Upper right => X: 7.7073, Y= 9.076
#       Lower right => X: 7.7073, Y= 9.2049
#       Lower left => X: 6.1124, Y= 9.2096
#   Line 65 has content: 'Common Stock, $0.00000625 par value per share'.
#     Its bounding box is:
#       Upper left => X: 0.6399, Y= 9.2956
#       Upper right => X: 3.2615, Y= 9.2956
#       Lower right => X: 3.2615, Y= 9.434
#       Lower left => X: 0.6399, Y= 9.4245
#   Line 66 has content: '7,583,440,247 shares'.
#     Its bounding box is:
#       Upper left => X: 6.5517, Y= 9.3194
#       Upper right => X: 7.7121, Y= 9.3147
#       Lower right => X: 7.7121, Y= 9.4531
#       Lower left => X: 6.5517, Y= 9.4579
#   Selection Mark 0 is selected.
#     Its bounding box is:
#       Upper left => X: 0.6572, Y= 1.7653
#       Upper right => X: 0.7809, Y= 1.7653
#       Lower right => X: 0.7809, Y= 1.8873
#       Lower left => X: 0.6572, Y= 1.8873
#   Selection Mark 1 is unselected.
#     Its bounding box is:
#       Upper left => X: 0.6611, Y= 2.6871
#       Upper right => X: 0.7835, Y= 2.6871
#       Lower right => X: 0.7835, Y= 2.8103
#       Lower left => X: 0.6611, Y= 2.8103
#   Selection Mark 2 is selected.
#     Its bounding box is:
#       Upper left => X: 4.2406, Y= 6.5435
#       Upper right => X: 4.3391, Y= 6.5435
#       Lower right => X: 4.3391, Y= 6.6413
#       Lower left => X: 4.2406, Y= 6.6413
#   Selection Mark 3 is unselected.
#     Its bounding box is:
#       Upper left => X: 4.7086, Y= 6.5447
#       Upper right => X: 4.8033, Y= 6.5447
#       Lower right => X: 4.8033, Y= 6.6375
#       Lower left => X: 4.7086, Y= 6.6375
#   Selection Mark 4 is selected.
#     Its bounding box is:
#       Upper left => X: 1.9626, Y= 7.0222
#       Upper right => X: 2.0623, Y= 7.0222
#       Lower right => X: 2.0623, Y= 7.1187
#       Lower left => X: 1.9626, Y= 7.1187
#   Selection Mark 5 is unselected.
#     Its bounding box is:
#       Upper left => X: 2.4205, Y= 7.0234
#       Upper right => X: 2.5139, Y= 7.0234
#       Lower right => X: 2.5139, Y= 7.1174
#       Lower left => X: 2.4205, Y= 7.1174
#   Selection Mark 6 is selected.
#     Its bounding box is:
#       Upper left => X: 1.8588, Y= 7.7045
#       Upper right => X: 1.9573, Y= 7.7045
#       Lower right => X: 1.9573, Y= 7.8011
#       Lower left => X: 1.8588, Y= 7.8011
#   Selection Mark 7 is unselected.
#     Its bounding box is:
#       Upper left => X: 6.2252, Y= 7.7045
#       Upper right => X: 6.3199, Y= 7.7045
#       Lower right => X: 6.3199, Y= 7.7998
#       Lower left => X: 6.2252, Y= 7.7998
#   Selection Mark 8 is unselected.
#     Its bounding box is:
#       Upper left => X: 1.7804, Y= 7.8803
#       Upper right => X: 1.8764, Y= 7.8803
#       Lower right => X: 1.8764, Y= 7.9755
#       Lower left => X: 1.7804, Y= 7.9755
#   Selection Mark 9 is unselected.
#     Its bounding box is:
#       Upper left => X: 6.7894, Y= 7.8815
#       Upper right => X: 6.884, Y= 7.8815
#       Lower right => X: 6.884, Y= 7.9768
#       Lower left => X: 6.7894, Y= 7.9768
#   Selection Mark 10 is unselected.
#     Its bounding box is:
#       Upper left => X: 6.7843, Y= 8.0534
#       Upper right => X: 6.879, Y= 8.0534
#       Lower right => X: 6.879, Y= 8.1474
#       Lower left => X: 6.7843, Y= 8.1474
#   Selection Mark 11 is unselected.
#     Its bounding box is:
#       Upper left => X: 6.5389, Y= 8.4099
#       Upper right => X: 6.6298, Y= 8.4099
#       Lower right => X: 6.6298, Y= 8.5013
#       Lower left => X: 6.5389, Y= 8.5013
#   Selection Mark 12 is unselected.
#     Its bounding box is:
#       Upper left => X: 6.7881, Y= 8.6098
#       Upper right => X: 6.884, Y= 8.6098
#       Lower right => X: 6.884, Y= 8.7051
#       Lower left => X: 6.7881, Y= 8.7051
#   Selection Mark 13 is selected.
#     Its bounding box is:
#       Upper left => X: 7.2397, Y= 8.6136
#       Upper right => X: 7.3369, Y= 8.6136
#       Lower right => X: 7.3369, Y= 8.7089
#       Lower left => X: 7.2397, Y= 8.7089
# The following tables were extracted:
#   Table 0 has 5 rows and 3 columns.
#     Cell (0, 0) has kind 'columnHeader' and content: 'Title of each class'.
#     Cell (0, 1) has kind 'columnHeader' and content: 'Trading Symbol'.
#     Cell (0, 2) has kind 'columnHeader' and content: 'Name of exchange on which registered'.
#     Cell (1, 0) has kind 'content' and content: 'Common stock, $0.00000625 par value per share'.
#     Cell (1, 1) has kind 'content' and content: 'MSFT'.
#     Cell (1, 2) has kind 'content' and content: 'NASDAQ'.
#     Cell (2, 0) has kind 'content' and content: '2.125% Notes due 2021'.
#     Cell (2, 1) has kind 'content' and content: 'MSFT'.
#     Cell (2, 2) has kind 'content' and content: 'NASDAQ'.
#     Cell (3, 0) has kind 'content' and content: '3.125% Notes due 2028'.
#     Cell (3, 1) has kind 'content' and content: 'MSFT'.
#     Cell (3, 2) has kind 'content' and content: 'NASDAQ'.
#     Cell (4, 0) has kind 'content' and content: '2.625% Notes due 2033'.
#     Cell (4, 1) has kind 'content' and content: 'MSFT'.
#     Cell (4, 2) has kind 'content' and content: 'NASDAQ'.
#   Table 1 has 2 rows and 2 columns.
#     Cell (0, 0) has kind 'columnHeader' and content: 'Class'.
#     Cell (0, 1) has kind 'columnHeader' and content: 'Outstanding as of April 24, 2020'.
#     Cell (1, 0) has kind 'content' and content: 'Common Stock, $0.00000625 par value per share'.
#     Cell (1, 1) has kind 'content' and content: '7,583,440,247 shares'.

# %% [markdown]
# ## Invoice Examples

# %%
invoice_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-invoice.pdf"

poller = client.begin_analyze_document_from_url("prebuilt-invoice", invoice_url)
result = poller.result()

for i, document in enumerate(result.documents):
    print(f"Document {i}:")

    if "VendorName" in document.fields:
        vendor_name_field = document.fields["VendorName"]
        if vendor_name_field.value_type == "string":
            vendor_name = vendor_name_field.value
            print(f"Vendor Name: '{vendor_name}', with confidence {vendor_name_field.confidence}")

    if "CustomerName" in document.fields:
        customer_name_field = document.fields["CustomerName"]
        if customer_name_field.value_type == "string":
            customer_name = customer_name_field.value
            print(f"Customer Name: '{customer_name}', with confidence {customer_name_field.confidence}")

    if "Items" in document.fields:
        items_field = document.fields["Items"]
        if items_field.value_type == "list":
            for item_field in items_field.value:
                print("Item:")
                if item_field.value_type == "dictionary":
                    item_fields = item_field.value

                    if "Description" in item_fields:
                        item_description_field = item_fields["Description"]
                        item_description = item_description_field.value
                        print(f"  Description: '{item_description}', with confidence {item_description_field.confidence}")

                    if "Amount" in item_fields:
                        item_amount_field = item_fields["Amount"]
                        item_amount = item_amount_field.value
                        print(f"  Amount: '{item_amount}', with confidence {item_amount_field.confidence}")

    if "SubTotal" in document.fields:
        sub_total_field = document.fields["SubTotal"]
        sub_total = sub_total_field.value
        print(f"Sub Total: '{sub_total}', with confidence {sub_total_field.confidence}")

    if "TotalTax" in document.fields:
        total_tax_field = document.fields["TotalTax"]
        total_tax = total_tax_field.value
        print(f"Total Tax: '{total_tax}', with confidence {total_tax_field.confidence}")

    if "InvoiceTotal" in document.fields:
        invoice_total_field = document.fields["InvoiceTotal"]
        invoice_total = invoice_total_field.value
        print(f"Invoice Total: '{invoice_total}', with confidence {invoice_total_field.confidence}")
# Out:
# Document 0:
# Vendor Name: 'CONTOSO LTD.', with confidence 0.93
# Customer Name: 'MICROSOFT CORPORATION', with confidence 0.915
# Item:
#   Description: 'Test for 23 fields', with confidence 0.914
#   Amount: '$100.0', with confidence 0.913
# Sub Total: '$100.0', with confidence 0.969
# Total Tax: '$10.0', with confidence 0.97
# Invoice Total: '$110.0', with confidence 0.97

# %%
invoice_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-invoice.pdf"

poller = client.begin_analyze_document_from_url("prebuilt-invoice", invoice_url)
invoices = poller.result()

for idx, invoice in enumerate(invoices.documents):
    print("--------Recognizing invoice #{}--------".format(idx + 1))
    vendor_name = invoice.fields.get("VendorName")
    if vendor_name:
        print(
            "Vendor Name: {} has confidence: {}".format(
                vendor_name.value, vendor_name.confidence
            )
        )
    vendor_address = invoice.fields.get("VendorAddress")
    if vendor_address:
        print(
            "Vendor Address: {} has confidence: {}".format(
                vendor_address.value, vendor_address.confidence
            )
        )
    vendor_address_recipient = invoice.fields.get("VendorAddressRecipient")
    if vendor_address_recipient:
        print(
            "Vendor Address Recipient: {} has confidence: {}".format(
                vendor_address_recipient.value, vendor_address_recipient.confidence
            )
        )
    customer_name = invoice.fields.get("CustomerName")
    if customer_name:
        print(
            "Customer Name: {} has confidence: {}".format(
                customer_name.value, customer_name.confidence
            )
        )
    customer_id = invoice.fields.get("CustomerId")
    if customer_id:
        print(
            "Customer Id: {} has confidence: {}".format(
                customer_id.value, customer_id.confidence
            )
        )
    customer_address = invoice.fields.get("CustomerAddress")
    if customer_address:
        print(
            "Customer Address: {} has confidence: {}".format(
                customer_address.value, customer_address.confidence
            )
        )
    customer_address_recipient = invoice.fields.get("CustomerAddressRecipient")
    if customer_address_recipient:
        print(
            "Customer Address Recipient: {} has confidence: {}".format(
                customer_address_recipient.value,
                customer_address_recipient.confidence,
            )
        )
    invoice_id = invoice.fields.get("InvoiceId")
    if invoice_id:
        print(
            "Invoice Id: {} has confidence: {}".format(
                invoice_id.value, invoice_id.confidence
            )
        )
    invoice_date = invoice.fields.get("InvoiceDate")
    if invoice_date:
        print(
            "Invoice Date: {} has confidence: {}".format(
                invoice_date.value, invoice_date.confidence
            )
        )
    invoice_total = invoice.fields.get("InvoiceTotal")
    if invoice_total:
        print(
            "Invoice Total: {} has confidence: {}".format(
                invoice_total.value, invoice_total.confidence
            )
        )
    due_date = invoice.fields.get("DueDate")
    if due_date:
        print(
            "Due Date: {} has confidence: {}".format(
                due_date.value, due_date.confidence
            )
        )
    purchase_order = invoice.fields.get("PurchaseOrder")
    if purchase_order:
        print(
            "Purchase Order: {} has confidence: {}".format(
                purchase_order.value, purchase_order.confidence
            )
        )
    billing_address = invoice.fields.get("BillingAddress")
    if billing_address:
        print(
            "Billing Address: {} has confidence: {}".format(
                billing_address.value, billing_address.confidence
            )
        )
    billing_address_recipient = invoice.fields.get("BillingAddressRecipient")
    if billing_address_recipient:
        print(
            "Billing Address Recipient: {} has confidence: {}".format(
                billing_address_recipient.value,
                billing_address_recipient.confidence,
            )
        )
    shipping_address = invoice.fields.get("ShippingAddress")
    if shipping_address:
        print(
            "Shipping Address: {} has confidence: {}".format(
                shipping_address.value, shipping_address.confidence
            )
        )
    shipping_address_recipient = invoice.fields.get("ShippingAddressRecipient")
    if shipping_address_recipient:
        print(
            "Shipping Address Recipient: {} has confidence: {}".format(
                shipping_address_recipient.value,
                shipping_address_recipient.confidence,
            )
        )
    print("Invoice items:")
    for idx, item in enumerate(invoice.fields.get("Items").value):
        print("...Item #{}".format(idx + 1))
        item_description = item.value.get("Description")
        if item_description:
            print(
                "......Description: {} has confidence: {}".format(
                    item_description.value, item_description.confidence
                )
            )
        item_quantity = item.value.get("Quantity")
        if item_quantity:
            print(
                "......Quantity: {} has confidence: {}".format(
                    item_quantity.value, item_quantity.confidence
                )
            )
        unit = item.value.get("Unit")
        if unit:
            print(
                "......Unit: {} has confidence: {}".format(
                    unit.value, unit.confidence
                )
            )
        unit_price = item.value.get("UnitPrice")
        if unit_price:
            print(
                "......Unit Price: {} has confidence: {}".format(
                    unit_price.value, unit_price.confidence
                )
            )
        product_code = item.value.get("ProductCode")
        if product_code:
            print(
                "......Product Code: {} has confidence: {}".format(
                    product_code.value, product_code.confidence
                )
            )
        item_date = item.value.get("Date")
        if item_date:
            print(
                "......Date: {} has confidence: {}".format(
                    item_date.value, item_date.confidence
                )
            )
        tax = item.value.get("Tax")
        if tax:
            print(
                "......Tax: {} has confidence: {}".format(tax.value, tax.confidence)
            )
        amount = item.value.get("Amount")
        if amount:
            print(
                "......Amount: {} has confidence: {}".format(
                    amount.value, amount.confidence
                )
            )
    subtotal = invoice.fields.get("SubTotal")
    if subtotal:
        print(
            "Subtotal: {} has confidence: {}".format(
                subtotal.value, subtotal.confidence
            )
        )
    total_tax = invoice.fields.get("TotalTax")
    if total_tax:
        print(
            "Total Tax: {} has confidence: {}".format(
                total_tax.value, total_tax.confidence
            )
        )
    previous_unpaid_balance = invoice.fields.get("PreviousUnpaidBalance")
    if previous_unpaid_balance:
        print(
            "Previous Unpaid Balance: {} has confidence: {}".format(
                previous_unpaid_balance.value, previous_unpaid_balance.confidence
            )
        )
    amount_due = invoice.fields.get("AmountDue")
    if amount_due:
        print(
            "Amount Due: {} has confidence: {}".format(
                amount_due.value, amount_due.confidence
            )
        )
    service_start_date = invoice.fields.get("ServiceStartDate")
    if service_start_date:
        print(
            "Service Start Date: {} has confidence: {}".format(
                service_start_date.value, service_start_date.confidence
            )
        )
    service_end_date = invoice.fields.get("ServiceEndDate")
    if service_end_date:
        print(
            "Service End Date: {} has confidence: {}".format(
                service_end_date.value, service_end_date.confidence
            )
        )
    service_address = invoice.fields.get("ServiceAddress")
    if service_address:
        print(
            "Service Address: {} has confidence: {}".format(
                service_address.value, service_address.confidence
            )
        )
    service_address_recipient = invoice.fields.get("ServiceAddressRecipient")
    if service_address_recipient:
        print(
            "Service Address Recipient: {} has confidence: {}".format(
                service_address_recipient.value,
                service_address_recipient.confidence,
            )
        )
    remittance_address = invoice.fields.get("RemittanceAddress")
    if remittance_address:
        print(
            "Remittance Address: {} has confidence: {}".format(
                remittance_address.value, remittance_address.confidence
            )
        )
    remittance_address_recipient = invoice.fields.get("RemittanceAddressRecipient")
    if remittance_address_recipient:
        print(
            "Remittance Address Recipient: {} has confidence: {}".format(
                remittance_address_recipient.value,
                remittance_address_recipient.confidence,
            )
        )
    print("----------------------------------------")
